# %% [markdown]
# <a href="https://colab.research.google.com/github/banned-from-uni/SWELL-DL/blob/main/Feature-For-Loop-Plots-Different-Seeds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn

# %%
accuracies = {'MEAN_RR(1)':0.600102961063385,'MEDIAN_RR(2)':0.5644845366477966,'HR(3)':0.6941877603530884,
              'pNN25(4)':0.8326981663703918,'SDSD(5)':0.8760544061660767,'SD1(6)':0.8763255476951599,
              'RMSSD(7)':0.8784976601600647,'LF(8)':0.9483057260513306,'VLF(9)':0.9774566888809204,
              'VLF_PCT(10)':0.9664652943611145,'SDRR_RMSSD_REL_RR(11)':0.9754003882408142,'LF_PCT(12)':0.9733684062957764,
              'LF_NU(13)':0.9847192764282227,'HF_NU(14)':0.984024703502655,'TP(15)':0.9905531406402588,
              'HF_LF(16)':0.9767346978187561,'HF_PCT(17)':0.9853986501693726,'LF_HF(18)':0.9900047779083252,
              'higuci(19)':0.9896910190582275,'sampen(20)':0.9928988814353943,'KURT_REL_RR(21)':0.9935904145240784,
              'KURT(22)':0.9958020448684692,'SDSD_REL_RR(23)':0.9884876608848572,'RMSSD_REL_RR(24)':0.9963352084159851,
              'HF(25)':0.9921250939369202,'SDRR_REL_RR(26)':0.9966550469398499,'pNN50(27)':0.9958873391151428,
              'SD2(28)':0.9994455575942993,'SDRR(29)':0.98568195104599,'MEDIAN_REL_RR(30)':0.9995613098144531,
              'SKEW_REL_RR(31)':0.9948515892028809,'SKEW(32)':0.9998476505279541,'SDRR_RMSSD(33)':0.9999330043792725,
              'MEAN_REL_RR(34)':0.9997349381446838}

# %%
accuracies_sr = pd.Series(accuracies)

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
plt.figure(figsize=(13,6),dpi=300)
seaborn.lineplot(data=accuracies)

plt.xlabel("Feature Labels")
plt.ylabel("Cumulative Accuracy")
plt.title("Comparison of Cumulative Accuracies of ANOVA-sorted Features")

plt.xticks(rotation=90)
plt.xticks([_ for _ in range(0,34)])
plt.grid();

# %%
plt.figure(figsize=(13,6),dpi=300)
seaborn.barplot(x=accuracies_sr.index,y=accuracies_sr.values)

plt.xlabel("Feature Labels")
plt.ylabel("Cumulative Accuracy")
plt.title("Comparison of Cumulative Accuracies of ANOVA-sorted Features")

plt.yticks([i/10 for i in range(0,11)])
plt.xticks(rotation=90);
