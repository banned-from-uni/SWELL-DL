# %% [markdown]
# <a href="https://colab.research.google.com/github/banned-from-uni/SWELL-DL/blob/main/Feature-For-Loop-Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn

# %%
accuracies = {'MEAN_RR(1)':0.5985005497932434,'MEDIAN_RR(2)':0.6346003413200378,'HR(3)':0.7193479537963867,
              'pNN25(4)':0.8031572699546814,'SDSD(5)':0.8489811420440674,'SD1(6)':0.8954477906227112,
              'RMSSD(7)':0.8721306920051575,'LF(8)':0.9328575134277344,'VLF(9)':0.917412281036377,
              'VLF_PCT(10)':0.9472395181655884,'SDRR_RMSSD_REL_RR(11)':0.9782243967056274,'LF_PCT(12)':0.9739411473274231,
              'LF_NU(13)':0.9833301305770874,'HF_NU(14)':0.9714705348014832,'TP(15)':0.9931090474128723,
              'HF_LF(16)':0.9822730422019958,'HF_PCT(17)':0.989020824432373,'LF_HF(18)':0.9828670620918274,
              'higuci(19)':0.9147070646286011,'sampen(20)':0.9708185791969299,'KURT_REL_RR(21)':0.9879088401794434,
              'KURT(22)':0.9922073483467102,'SDSD_REL_RR(23)':0.9958995580673218,'RMSSD_REL_RR(24)':0.9887222647666931,
              'HF(25)':0.9929689168930054,'SDRR_REL_RR(26)':0.9948850870132446,'pNN50(27)':0.9988241195678711,
              'SD2(28)':0.9977700114250183,'SDRR(29)':0.9973344206809998,'MEDIAN_REL_RR(30)':0.999390721321106,
              'SKEW_REL_RR(31)':0.9986565113067627,'SKEW(32)':0.9990982413291931,'SDRR_RMSSD(33)':0.9985560178756714,
              'MEAN_REL_RR(34)':0.999631404876709}

# %%
accuracies_sr = pd.Series(accuracies)

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
plt.figure(figsize=(13,6),dpi=300)
seaborn.lineplot(data=accuracies)

plt.xlabel("Feature Labels")
plt.ylabel("Cumulative Accuracy")
plt.title("Comparison of Cumulative Accuracies of ANOVA-sorted Features")

plt.xticks(rotation=90)
plt.xticks([_ for _ in range(0,34)])
plt.grid();

# %%
plt.figure(figsize=(13,6),dpi=300)
seaborn.barplot(x=accuracies_sr.index,y=accuracies_sr.values)

plt.xlabel("Feature Labels")
plt.ylabel("Cumulative Accuracy")
plt.title("Comparison of Cumulative Accuracies of ANOVA-sorted Features")

plt.yticks([i/10 for i in range(0,11)])
plt.xticks(rotation=90);
